# %%
name = input("Введіть ваше ім'я: ")
print("Привіт,", name, "!")
age = input("Введіть ваш вік: ")
print("Вам", age, "років.")
print("Гарного дня!")
# Out:
# Привіт, Roman !
# Вам 20 років.
# Гарного дня!
